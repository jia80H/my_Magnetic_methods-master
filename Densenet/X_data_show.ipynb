# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
os.chdir('/home/jiajianhao/文档/cnn/Magnetic_methods-master')
from Utils.Utils_colab import *

# %%
# X_train 图像数据集
hdf5_path = './test_data/V12_YOLO_par_3_9600.hdf5'
X_train, X_dev, X_test, Y_train, Y_dev, Y_test = load_dataset_train_dev_test(hdf5_path)

# 随机选择一个图像进行可视化
random_index = np.random.randint(0, X_train.shape[0])
sample_image = X_train[random_index]

# 显示图像
plt.imshow(sample_image)
plt.title(f"Sample Image at Index {random_index}")
plt.show()

# %%
# 灰度转rgb后区别对比

# 一个图像进行可视化
# np.random.seed()
index1 = np.random.randint(0, X_train.shape[0])
sample_image_gray = X_train[random_index]


# 转rgb
X_train_rgb = gray_to_rgb(X_train)
index1 = np.random.randint(0, X_train.shape[0])
sample_image_rgb = X_train_rgb[random_index]

# 显示图像
plt.figure()
plt.subplot(121)
plt.axis('on')
plt.xlabel('Position X (m)')
plt.ylabel('Position Y (m)')
plt.title(f"Sample Image at Index {random_index}")
plt.imshow(sample_image_gray)
plt.subplot(122)
plt.axis('on')
plt.xlabel('Position X (m)')
plt.ylabel('Position Y (m)')
plt.title(f"Sample Image at Index {random_index}")
plt.imshow(sample_image_rgb)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
